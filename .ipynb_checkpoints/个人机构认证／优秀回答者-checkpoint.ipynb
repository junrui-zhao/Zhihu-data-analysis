# %% [markdown]
# ## 1.引入包

# %%
#-*- coding=utf-8 -*-
import pandas as pd
import pylab
import collections
import numpy as np
import matplotlib.pyplot as plt
from collections import defaultdict
import statsmodels.api as sm
from pylab import *

# %% [markdown]
# ## 2. 画双对数坐标

# %%
def drawloglog(data,title):
    feature_count_pairs = collections.Counter(data).most_common()
    feature_value = zip(*feature_count_pairs)[0]
    count = zip(*feature_count_pairs)[1]
    plt.title(title)
    plt.loglog(feature_value, count,'.',color='blue')
    plt.show()

# %% [markdown]
# ## 3. 带指数截断的幂律分布拟合

# %%
def powerLawExponentialCutOffPlot(datax,datay, xlab, ylab):
    '''
    Plot fitted powerLaw distribution with Exponential CutOff
    '''
    t = datax
    #r = np.array(range(len(data))) +1
    r = datay
    y = np.log(r[1:len(r)-600])
    x1 = np.log(t[1:len(r)-600])
    x2 = t[1:len(r)-600]
    x = np.column_stack((x1,x2))
    x = sm.add_constant(x, prepend=True)
    res = sm.OLS(y,x).fit()
    L,alpha,lambde = res.params
    r2 = res.rsquared
    plt.plot(t,r,".",color="blue",alpha=1)
    plt.plot(t[5:len(r)-600], (np.exp(L) * t ** alpha * np.exp(lambde * t))[5:len(r)-600],"r-",linewidth=2)
    plt.xscale('log'); plt.yscale('log')
    plt.ylim(ymax = 0.09)
    plt.xlabel(xlab, fontsize = 10)
    plt.ylabel(ylab, fontsize = 10)
    plt.text(3, 0.001, "alpha="+ str(round(alpha,3))+"\nlambda="+str(round(lambde,3)) ,fontsize=10);
    plt.show()
    print L,alpha,lambde, r2

# %% [markdown]
# ## 4.主程序

# %% [markdown]
# ### 4.1 优秀回答者答案数top500答案分析

# %%
Location = r'../数据/论文用/优秀回答者答案数top500答案情况.csv'
#df = pd.read_csv(Location,dtype={'user_detail.userid':np.str,'user_detail.following_count':np.int32})
df = pd.read_csv(Location)

# %%
feature_count_pairs = collections.Counter(df['comment_count']).most_common()
#feature_value = zip(*feature_count_pairs)[0]
sorted_count = sorted(feature_count_pairs, key=itemgetter(0))
X = zip(*sorted_count)[0]
Y = zip(*sorted_count)[1]
pY = [n/float(sum(Y)) for n in Y]
def powerLawExponentialCutOffPlot(datax,datay, xlab, ylab):
    '''
    Plot fitted powerLaw distribution with Exponential CutOff
    '''
    t = datax
    #r = np.array(range(len(data))) +1
    r = datay
    y = np.log(r[1:len(r)-400])
    x1 = np.log(t[1:len(r)-400])
    x2 = t[1:len(r)-400]
    x = np.column_stack((x1,x2))
    x = sm.add_constant(x, prepend=True)
    res = sm.OLS(y,x).fit()
    L,alpha,lambde = res.params
    r2 = res.rsquared
    plt.plot(t,r,".",color="blue",alpha=1)
    plt.plot(t[5:len(r)-400], (np.exp(L) * t ** alpha * np.exp(lambde * t))[5:len(r)-400],"r-",linewidth=2)
    plt.xscale('log'); plt.yscale('log')
    plt.ylim(ymax = 0.08)
    plt.xlabel(xlab, fontsize = 10)
    plt.ylabel(ylab, fontsize = 10)
    plt.text(3, 0.001, "alpha="+ str(round(alpha,3))+"\nlambda="+str(round(lambde,3)) ,fontsize=10);
    plt.show()
    print L,alpha,lambde, r2
powerLawExponentialCutOffPlot(np.array(X),np.array(pY),"the number of comments-excellent user","p(k)")
# Out:
# /usr/local/lib/python2.7/site-packages/ipykernel_launcher.py:25: RuntimeWarning: divide by zero encountered in power
# -1.63927742974 -0.986824910657 -0.00711910279241 0.963082780332

# %%
feature_count_pairs = collections.Counter(df['voteup_count']).most_common()
#feature_value = zip(*feature_count_pairs)[0]
sorted_count = sorted(feature_count_pairs, key=itemgetter(0))
X = zip(*sorted_count)[0]
Y = zip(*sorted_count)[1]
pY = [n/float(sum(Y)) for n in Y]
def powerLawExponentialCutOffPlot(datax,datay, xlab, ylab):
    '''
    Plot fitted powerLaw distribution with Exponential CutOff
    '''
    t = datax
    #r = np.array(range(len(data))) +1
    r = datay
    y = np.log(r[1:len(r)-2500])
    x1 = np.log(t[1:len(r)-2500])
    x2 = t[1:len(r)-2500]
    x = np.column_stack((x1,x2))
    x = sm.add_constant(x, prepend=True)
    res = sm.OLS(y,x).fit()
    L,alpha,lambde = res.params
    r2 = res.rsquared
    plt.plot(t,r,".",color="blue",alpha=1)
    plt.plot(t[6:len(r)-2500], (np.exp(L) * t ** alpha * np.exp(lambde * t))[6:len(r)-2500],"r-",linewidth=2)
    plt.xscale('log'); plt.yscale('log')
    plt.ylim(ymax = 0.07)
    plt.xlabel(xlab, fontsize = 10)
    plt.ylabel(ylab, fontsize = 10)
    plt.text(3, 0.001, "alpha="+ str(round(alpha,3))+"\nlambda="+str(round(lambde,3)) ,fontsize=10);
    plt.show()
    print L,alpha,lambde, r2
powerLawExponentialCutOffPlot(np.array(X),np.array(pY),"the number of voteup-excellent user","p(k)")
# Out:
# /usr/local/lib/python2.7/site-packages/ipykernel_launcher.py:23: RuntimeWarning: divide by zero encountered in power
# -2.09679919167 -0.91773297031 -0.00151625676083 0.933762786498

# %%
feature_count_pairs = collections.Counter(df['thanks_count']).most_common()
#feature_value = zip(*feature_count_pairs)[0]
sorted_count = sorted(feature_count_pairs, key=itemgetter(0))
X = zip(*sorted_count)[0]
Y = zip(*sorted_count)[1]
pY = [n/float(sum(Y)) for n in Y]
def powerLawExponentialCutOffPlot(datax,datay, xlab, ylab):
    '''
    Plot fitted powerLaw distribution with Exponential CutOff
    '''
    t = datax
    #r = np.array(range(len(data))) +1
    r = datay
    y = np.log(r[1:len(r)-2200])
    x1 = np.log(t[1:len(r)-2200])
    x2 = t[1:len(r)-2200]
    x = np.column_stack((x1,x2))
    x = sm.add_constant(x, prepend=True)
    res = sm.OLS(y,x).fit()
    L,alpha,lambde = res.params
    r2 = res.rsquared
    plt.plot(t,r,".",color="blue",alpha=1)
    plt.plot(t[6:len(r)-2200], (np.exp(L) * t ** alpha * np.exp(lambde * t))[6:len(r)-2200],"r-",linewidth=2)
    plt.xscale('log'); plt.yscale('log')
    plt.ylim(ymax = 0.2)
    plt.xlabel(xlab, fontsize = 10)
    plt.ylabel(ylab, fontsize = 10)
    plt.text(3, 0.001, "alpha="+ str(round(alpha,3))+"\nlambda="+str(round(lambde,3)) ,fontsize=10);
    plt.show()
    print L,alpha,lambde, r2
powerLawExponentialCutOffPlot(np.array(X),np.array(pY),"the number of thanks-excellent user","p(k)")
# Out:
# /usr/local/lib/python2.7/site-packages/ipykernel_launcher.py:23: RuntimeWarning: divide by zero encountered in power
# -1.55677727029 -1.08250636673 -0.00311591721357 0.934691844316

# %% [markdown]
# ### 4.2 机构认证回答者top500

# %%
Location = r'../数据/论文用/机构认证答案数top500答案情况.csv'
#df = pd.read_csv(Location,dtype={'user_detail.userid':np.str,'user_detail.following_count':np.int32})
df = pd.read_csv(Location)

# %%
feature_count_pairs = collections.Counter(df['comment_count']).most_common()
#feature_value = zip(*feature_count_pairs)[0]
sorted_count = sorted(feature_count_pairs, key=itemgetter(0))
X = zip(*sorted_count)[0]
Y = zip(*sorted_count)[1]
pY = [n/float(sum(Y)) for n in Y]
def powerLawExponentialCutOffPlot(datax,datay, xlab, ylab):
    '''
    Plot fitted powerLaw distribution with Exponential CutOff
    '''
    t = datax
    #r = np.array(range(len(data))) +1
    r = datay
    y = np.log(r[1:len(r)-950])
    x1 = np.log(t[1:len(r)-950])
    x2 = t[1:len(r)-950]
    x = np.column_stack((x1,x2))
    x = sm.add_constant(x, prepend=True)
    res = sm.OLS(y,x).fit()
    L,alpha,lambde = res.params
    r2 = res.rsquared
    plt.plot(t,r,".",color="blue",alpha=1)
    plt.plot(t[3:len(r)-950], (np.exp(L) * t ** alpha * np.exp(lambde * t))[3:len(r)-950],"r-",linewidth=2)
    plt.xscale('log'); plt.yscale('log')
    plt.ylim(ymax = 0.05)
    plt.xlabel(xlab, fontsize = 10)
    plt.ylabel(ylab, fontsize = 10)
    plt.text(3, 0.001, "alpha="+ str(round(alpha,3))+"\nlambda="+str(round(lambde,3)) ,fontsize=10);
    plt.show()
    print L,alpha,lambde, r2
powerLawExponentialCutOffPlot(np.array(X),np.array(pY),"the number of comments-orgnization","p(k)")
# Out:
# /usr/local/lib/python2.7/site-packages/ipykernel_launcher.py:23: RuntimeWarning: divide by zero encountered in power
# -3.36659518576 -0.373152805492 -0.0111025024821 0.805791520575

# %%
feature_count_pairs = collections.Counter(df['voteup_count']).most_common()
#feature_value = zip(*feature_count_pairs)[0]
sorted_count = sorted(feature_count_pairs, key=itemgetter(0))
X = zip(*sorted_count)[0]
Y = zip(*sorted_count)[1]
pY = [n/float(sum(Y)) for n in Y]
def powerLawExponentialCutOffPlot(datax,datay, xlab, ylab):
    '''
    Plot fitted powerLaw distribution with Exponential CutOff
    '''
    t = datax
    #r = np.array(range(len(data))) +1
    r = datay
    y = np.log(r[1:len(r)-950])
    x1 = np.log(t[1:len(r)-950])
    x2 = t[1:len(r)-950]
    x = np.column_stack((x1,x2))
    x = sm.add_constant(x, prepend=True)
    res = sm.OLS(y,x).fit()
    L,alpha,lambde = res.params
    r2 = res.rsquared
    plt.plot(t,r,".",color="blue",alpha=1)
    plt.plot(t[3:len(r)-950], (np.exp(L) * t ** alpha * np.exp(lambde * t))[3:len(r)-950],"r-",linewidth=2)
    plt.xscale('log'); plt.yscale('log')
    plt.ylim(ymax = 0.015)
    plt.xlabel(xlab, fontsize = 10)
    plt.ylabel(ylab, fontsize = 10)
    plt.text(3, 0.0008, "alpha="+ str(round(alpha,3))+"\nlambda="+str(round(lambde,3)) ,fontsize=10);
    plt.show()
    print L,alpha,lambde, r2
powerLawExponentialCutOffPlot(np.array(X),np.array(pY),"the number of voteup-orgnization","p(k)")
# Out:
# /usr/local/lib/python2.7/site-packages/ipykernel_launcher.py:23: RuntimeWarning: divide by zero encountered in power
# -4.41554864168 -0.405506557753 -0.00159600822199 0.559319017693

# %%
feature_count_pairs = collections.Counter(df['thanks_count']).most_common()
#feature_value = zip(*feature_count_pairs)[0]
sorted_count = sorted(feature_count_pairs, key=itemgetter(0))
X = zip(*sorted_count)[0]
Y = zip(*sorted_count)[1]
pY = [n/float(sum(Y)) for n in Y]
def powerLawExponentialCutOffPlot(datax,datay, xlab, ylab):
    '''
    Plot fitted powerLaw distribution with Exponential CutOff
    '''
    t = datax
    #r = np.array(range(len(data))) +1
    r = datay
    y = np.log(r[1:len(r)-1300])
    x1 = np.log(t[1:len(r)-1300])
    x2 = t[1:len(r)-1300]
    x = np.column_stack((x1,x2))
    x = sm.add_constant(x, prepend=True)
    res = sm.OLS(y,x).fit()
    L,alpha,lambde = res.params
    r2 = res.rsquared
    plt.plot(t,r,".",color="blue",alpha=1)
    plt.plot(t[5:len(r)-1300], (np.exp(L) * t ** alpha * np.exp(lambde * t))[5:len(r)-1300],"r-",linewidth=2)
    plt.xscale('log'); plt.yscale('log')
    plt.ylim(ymax = 0.04)
    plt.xlabel(xlab, fontsize = 10)
    plt.ylabel(ylab, fontsize = 10)
    plt.text(3, 0.0008, "alpha="+ str(round(alpha,3))+"\nlambda="+str(round(lambde,3)) ,fontsize=10);
    plt.show()
    print L,alpha,lambde, r2
powerLawExponentialCutOffPlot(np.array(X),np.array(pY),"the number of thanks-orgnization","p(k)")
# Out:
# /usr/local/lib/python2.7/site-packages/ipykernel_launcher.py:23: RuntimeWarning: divide by zero encountered in power
# -3.16815280312 -0.560136946364 -0.00484376608671 0.77813269828

# %% [markdown]
# ### 4.3 个人认证答案数top500答案情况

# %%
Location = r'../数据/论文用/个人认证答案数top500答案情况.csv'
#df = pd.read_csv(Location,dtype={'user_detail.userid':np.str,'user_detail.following_count':np.int32})
df = pd.read_csv(Location)

# %%
import statsmodels.api as sm
from pylab import *
feature_count_pairs = collections.Counter(df['comment_count']).most_common()
#feature_value = zip(*feature_count_pairs)[0]
sorted_count = sorted(feature_count_pairs, key=itemgetter(0))
X = zip(*sorted_count)[0]
Y = zip(*sorted_count)[1]
pY = [n/float(sum(Y)) for n in Y]
def powerLawExponentialCutOffPlot(datax,datay, xlab, ylab):
    '''
    Plot fitted powerLaw distribution with Exponential CutOff
    '''
    t = datax
    #r = np.array(range(len(data))) +1
    r = datay
    y = np.log(r[1:len(r)-500])
    x1 = np.log(t[1:len(r)-500])
    x2 = t[1:len(r)-500]
    x = np.column_stack((x1,x2))
    x = sm.add_constant(x, prepend=True)
    res = sm.OLS(y,x).fit()
    L,alpha,lambde = res.params
    r2 = res.rsquared
    plt.plot(t,r,".",color="blue",alpha=1)
    plt.plot(t[5:len(r)-500], (np.exp(L) * t ** alpha * np.exp(lambde * t))[5:len(r)-500],"r-",linewidth=2)
    plt.xscale('log'); plt.yscale('log')
    plt.ylim(ymax = 0.08)
    plt.xlabel(xlab, fontsize = 10)
    plt.ylabel(ylab, fontsize = 10)
    plt.text(3, 0.001, "alpha="+ str(round(alpha,3))+"\nlambda="+str(round(lambde,3)) ,fontsize=10);
    plt.show()
    print L,alpha,lambde, r2
powerLawExponentialCutOffPlot(np.array(X),np.array(pY),"the number of comments-identified user","p(k)")
# Out:
# /usr/local/lib/python2.7/site-packages/ipykernel_launcher.py:19: RuntimeWarning: divide by zero encountered in power
# -1.94762282256 -0.88628662346 -0.00599238655662 0.941833425283

# %%
import statsmodels.api as sm
from pylab import *
feature_count_pairs = collections.Counter(df['voteup_count']).most_common()
#feature_value = zip(*feature_count_pairs)[0]
sorted_count = sorted(feature_count_pairs, key=itemgetter(0))
X = zip(*sorted_count)[0]
Y = zip(*sorted_count)[1]
pY = [n/float(sum(Y)) for n in Y]
def powerLawExponentialCutOffPlot(datax,datay, xlab, ylab):
    '''
    Plot fitted powerLaw distribution with Exponential CutOff
    '''
    t = datax
    #r = np.array(range(len(data))) +1
    r = datay
    y = np.log(r[1:len(r)-2000])
    x1 = np.log(t[1:len(r)-2000])
    x2 = t[1:len(r)-2000]
    x = np.column_stack((x1,x2))
    x = sm.add_constant(x, prepend=True)
    res = sm.OLS(y,x).fit()
    L,alpha,lambde = res.params
    r2 = res.rsquared
    plt.plot(t,r,".",color="blue",alpha=1)
    plt.plot(t[7:len(r)-2000], (np.exp(L) * t ** alpha * np.exp(lambde * t))[7:len(r)-2000],"r-",linewidth=2)
    plt.xscale('log'); plt.yscale('log')
    plt.ylim(ymax = 0.05)
    plt.xlabel(xlab, fontsize = 10)
    plt.ylabel(ylab, fontsize = 10)
    plt.text(3, 0.001, "alpha="+ str(round(alpha,3))+"\nlambda="+str(round(lambde,3)) ,fontsize=10);
    plt.show()
    print L,alpha,lambde, r2
powerLawExponentialCutOffPlot(np.array(X),np.array(pY),"the number of voteup-identified user","p(k)")
# Out:
# /usr/local/lib/python2.7/site-packages/ipykernel_launcher.py:19: RuntimeWarning: divide by zero encountered in power
# -2.64618561031 -0.793724276172 -0.00155129303259 0.887730760945

# %%
feature_count_pairs = collections.Counter(df['thanks_count']).most_common()
#feature_value = zip(*feature_count_pairs)[0]
sorted_count = sorted(feature_count_pairs, key=itemgetter(0))
X = zip(*sorted_count)[0]
Y = zip(*sorted_count)[1]
pY = [n/float(sum(Y)) for n in Y]
def powerLawExponentialCutOffPlot(datax,datay, xlab, ylab):
    '''
    Plot fitted powerLaw distribution with Exponential CutOff
    '''
    t = datax
    #r = np.array(range(len(data))) +1
    r = datay
    y = np.log(r[1:len(r)-2000])
    x1 = np.log(t[1:len(r)-2000])
    x2 = t[1:len(r)-2000]
    x = np.column_stack((x1,x2))
    x = sm.add_constant(x, prepend=True)
    res = sm.OLS(y,x).fit()
    L,alpha,lambde = res.params
    r2 = res.rsquared
    plt.plot(t,r,".",color="blue",alpha=1)
    plt.plot(t[4:len(r)-2000], (np.exp(L) * t ** alpha * np.exp(lambde * t))[4:len(r)-2000],"r-",linewidth=2)
    plt.xscale('log'); plt.yscale('log')
    plt.ylim(ymax = 0.09)
    plt.xlabel(xlab, fontsize = 10)
    plt.ylabel(ylab, fontsize = 10)
    plt.text(3, 0.001, "alpha="+ str(round(alpha,3))+"\nlambda="+str(round(lambde,3)) ,fontsize=10);
    plt.show()
    print L,alpha,lambde, r2
powerLawExponentialCutOffPlot(np.array(X),np.array(pY),"the number of thanks-identified user","p(k)")
# Out:
# /usr/local/lib/python2.7/site-packages/ipykernel_launcher.py:25: RuntimeWarning: divide by zero encountered in power
# -1.98670060988 -0.935890442832 -0.00343629045371 0.914120244606
